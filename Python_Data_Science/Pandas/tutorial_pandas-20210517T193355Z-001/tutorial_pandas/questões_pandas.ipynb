# %%
import pandas as pd

# %% [markdown]
# Questão 1 - Na célula abaixo, crie um DataFrame `vendas_veiculos` igual a este:
# ![image.png](attachment:image.png)

# %%
#Resposta Questão 1

# %% [markdown]
# Questão 2 - Na célula abaixo, escreva o código para salvar este DataFrame no disco como um arquivo csv com o nome `vendas_veiculos.csv`.

# %%
#Resposta Questão 2

# %% [markdown]
# Questão 3 - Leia o seguinte dataset csv `housing_clean` em um DataFrame chamado `imoveis`, utilizando a primeira coluna como índice:

# %%
#Resposta Questão 3

# %% [markdown]
# Questão 4 - Selecione a coluna `renovation_type` de `housing_clean` e atribua o resultado à variável `renovacao`.

# %%
#Resposta Questão 4

# %% [markdown]
# Questão 5 - Selecione os registros com rótulos de índice ` 2`, `3`,` 5` e `8`, atribuindo o resultado à variável` amostras_imoveis` e obtenha o seguinte `DataFrame`.
#
# ![image.png](attachment:image.png)

# %%
#Resposta Questão 5

# %% [markdown]
# Questão 6 - Crie uma variável `df` contendo as colunas `price`, `space`, `city_area` e `max_floor` dos registros com os rótulos de índice` 0`,` 25`, `75` e` 100 `. Em outras palavras, gere o seguinte `DataFrame`:
#
# ![image.png](attachment:image.png)

# %%
#Resposta Questão 6

# %% [markdown]
# Questão 7 - Quais áreas da cidade (`city_area`)  estão presentes no dataset? (Sua resposta não deve incluir nenhuma duplicada.)

# %%
#Resposta Questão 7

# %% [markdown]
# Questão 8 - Qual o preço (`price`) máximo, médio e mínimo de um imóvel? Dica: Usar uma função para cada métrica.

# %%
#Resposta Questão 8

# %% [markdown]
# Questão 9 - Qual a quantidade de imóveis localizada em cada distrito (`city_area`)?

# %%
#Resposta Questão 9

# %% [markdown]
# Questão 10 - Crie um DataFrame `vake_district` contendo imoveis localizados no` Vake District`.

# %%
#Resposta Questão 10

# %% [markdown]
# Questão 11 - Remover todas as linhas que possuam alguma informação faltante e apresentar a dimensionalidade novo dataframe. (Quantidade de linhas x colunas)

# %%
#Resposta Questão 11
