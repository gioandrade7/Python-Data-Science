# %% [markdown]
# # Aula 1
#
# #### Fazendo as primeiras visualizações

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/giovanna/Documents/curso-matplotlib-preparando_ambiente/monitoramento_tempo.csv')

# %%
df.head()
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0   282.080000   1024.0      81.0               0.0                  0.0
# 1   282.080000   1024.0      81.0               0.0                  0.0
# 2   282.083252   1024.0      80.0               4.0                  0.0
# 3   282.091866   1024.0      80.0              18.0                  0.0
# 4   282.100481   1024.0      80.0              31.0                  0.0
#
#   dia_da_semana                 data
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
df['data'] = pd.to_datetime(df['data'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(df['data'], df['temperatura'])

# %%
plt.figure(figsize = (15, 8))
plt.plot(df['data'], df['temperatura'])

# %%
plt.figure(figsize = (15, 8))
plt.title('Temeperatura no tempo')
plt.plot(df['data'], df['temperatura'])

# %%
figura = plt.figure(figsize = (15, 8))
grafico = figura.add_axes([0, 0, 1, 1])

# %%
figura = plt.figure(figsize = (15, 8))
grafico = figura.add_axes([0, 0, 0.5, 0.5])
grafico.plot(df['data'], df['temperatura'])

grafico.set_title('Temperartura por ano')
# Out:
# Text(0.5, 1.0, 'Temperartura por ano')

# %%
fig = plt.figure(figsize = (15, 8))
grafico = fig.add_axes([0, 0, 1, 1])
grafico.plot(df['data'], df['temperatura'])

grafico.set_title('Temperartura por ano')
grafico.set_xlabel('Ano')
grafico.set_ylabel('Temperatura')
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
figura = plt.figure(figsize = (15, 8))
grafico = figura.add_axes([0, 0, 1, 1])
grafico.plot(df['data'], df['temperatura'])

grafico.set_title('Temperartura por ano', fontsize=25)
grafico.set_xlabel('Ano', fontsize = 20)
grafico.set_ylabel('Temperatura', fontsize = 20)
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
figura = plt.figure(figsize = (15, 8))
grafico = figura.add_axes([0, 0, 1, 1])
grafico.plot(df['data'], df['temperatura'])

grafico.set_title('Temperartura por ano', fontsize=25)
grafico.set_xlabel('Ano', fontsize = 20)
grafico.set_ylabel('Temperatura', fontsize = 20)
grafico.legend(['temperatura'], loc = 'upper right', fontsize = 15)

# %%
figura = plt.figure(figsize = (15, 8))
grafico = figura.add_axes([0.5, 0.5, 1, 1])
grafico.plot(df['data'], df['temperatura'], color = 'indigo')

grafico.set_title('Temperartura por ano', fontsize=25)
grafico.set_xlabel('Ano', fontsize = 20)
grafico.set_ylabel('Temperatura', fontsize = 20)
grafico.legend(['temperatura'], loc = 'upper right', fontsize = 15)

# %% [markdown]
# # Aula 2

# %% [markdown]
# ### Customizando nossas visualizações

# %%
figura = plt.figure(figsize = (15, 8))
grafico = figura.add_axes([0.5, 0.5, 1, 1])
grafico.plot(df['data'], df['temperatura'], color = 'indigo')

grafico.set_title('Temperartura por ano', fontsize=25)
grafico.set_xlabel('Ano', fontsize = 20)
grafico.set_ylabel('Temperatura', fontsize = 20)
grafico.legend(['temperatura'], loc = 'upper right', fontsize = 15)

# %%
figura = plt.figure(figsize = (15, 8))
grafico = figura.add_axes([0.5, 0.5, 1, 1])
grafico.plot(df['data'], df['temperatura'], color = 'indigo', lw = 0.4)

grafico.set_title('Temperartura por ano', fontsize=25)
grafico.set_xlabel('Ano', fontsize = 20)
grafico.set_ylabel('Temperatura', fontsize = 20)
grafico.legend(['temperatura'], loc = 'upper right', fontsize = 15)

# %%
figura = plt.figure(figsize = (15, 8))
grafico = figura.add_axes([0.5, 0.5, 1, 1])
grafico.plot(df['data'], df['temperatura'], color = 'indigo', ls = 'dotted')

grafico.set_title('Temperartura por ano', fontsize=25)
grafico.set_xlabel('Ano', fontsize = 20)
grafico.set_ylabel('Temperatura', fontsize = 20)
grafico.legend(['temperatura'], loc = 'upper right', fontsize = 15)

# %%
import datetime

# %%
figura = plt.figure(figsize = (15, 8))
grafico = figura.add_axes([0.5, 0.5, 1, 1])
grafico.plot(df['data'], df['temperatura'], color = 'indigo')

grafico.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
grafico.set_title('Temperartura por ano', fontsize=25)
grafico.set_xlabel('Ano', fontsize = 20)
grafico.set_ylabel('Temperatura', fontsize = 20)
grafico.legend(['temperatura'], loc = 'upper right', fontsize = 15)

# %%
figura = plt.figure(figsize = (15, 8))
grafico = figura.add_axes([0.5, 0.5, 1, 1])
grafico.plot(df['data'], df['temperatura'], color = 'indigo', marker = 'o')

grafico.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
grafico.set_title('Temperartura por ano', fontsize=25)
grafico.set_xlabel('Ano', fontsize = 20)
grafico.set_ylabel('Temperatura', fontsize = 20)
grafico.legend(['temperatura'], loc = 'upper right', fontsize = 15)

# %%
figura = plt.figure(figsize = (15, 8))
grafico = figura.add_axes([0.5, 0.5, 1, 1])
grafico.plot(df['data'], df['temperatura'], color = 'indigo')

grafico.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
grafico.set_title('Temperartura por ano', fontsize=25)
grafico.set_xlabel('Ano', fontsize = 20)
grafico.set_ylabel('Temperatura', fontsize = 20)
grafico.legend(['temperatura'], loc = 'upper right', fontsize = 15)
grafico.grid(True)

# %%
figura = plt.figure(figsize = (15, 8))

grafico = figura.add_axes([0, 0, 1, 1])
grafico2 = figura.add_axes([0.1, 0.5, 0.4, 0.4])

# %%
figura = plt.figure(figsize = (15, 8))

grafico = figura.add_axes([0, 0, 1, 1])
grafico2 = figura.add_axes([0.1, 0.5, 0.4, 0.4])

grafico.plot(df['data'], df['temperatura'], color = 'green')
grafico.set_title('Temperatura no memoneto', fontsize = 25, pad = 20)
grafico.legend(['Temperetaura'], loc = 'best', fontsize = 15)
grafico.grid(True)

# %%
figura = plt.figure(figsize = (15, 8))

grafico = figura.add_axes([0, 0, 1, 1])
grafico2 = figura.add_axes([0.1, 0.5, 0.4, 0.4])

grafico.plot(df['data'], df['temperatura'], color = 'green')
grafico.set_title('Temperatura no memoneto', fontsize = 25, pad = 20)
grafico.legend(['Temperetaura'], loc = 'best', fontsize = 15)
grafico.grid(True)
grafico.set_xlabel('Ano', fontsize=20)
grafico.set_ylabel('Temperatura', fontsize = 20)

grafico2.plot(df['data'], df['temperatura'], color = 'b')
grafico2.set_title('Temperatura no memoneto', fontsize = 15)
grafico2.legend(['Temperetaura'], loc = 'best', fontsize = 8)
grafico2.grid(True)
grafico2.set_xlabel('Ano', fontsize = 10)
grafico2.set_ylabel('Temperatura', fontsize=10)
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
figura = plt.figure(figsize = (15, 8))

grafico = figura.add_axes([0, 0, 1, 1])
grafico2 = figura.add_axes([0.7, 0.65, 0.3, 0.3])

grafico.plot(df['data'], df['temperatura'], color = 'green')
grafico.set_title('Temperatura no memoneto', fontsize = 25, pad = 20)
grafico.legend(['Temperetaura'], loc = 'lower right', fontsize = 15)
grafico.grid(True)
grafico.set_xlabel('Ano', fontsize=20)
grafico.set_ylabel('Temperatura', fontsize = 20)
grafico.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))

grafico2.plot(df['data'], df['temperatura'], color = 'b')
grafico2.set_title('Temperatura no memoneto', fontsize = 15)
grafico2.legend(['Temperetaura'], loc = 'best', fontsize = 8)
grafico2.grid(True)
grafico2.set_xlabel('Ano', fontsize = 10)
grafico2.set_ylabel('Temperatura', fontsize=10)
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
figura = plt.figure(figsize = (15, 8))

grafico = figura.add_axes([0, 0, 1, 1])
grafico2 = figura.add_axes([0.7, 0.65, 0.3, 0.3])

grafico.plot(df['data'], df['temperatura'], color = 'green')
grafico.set_title('Temperatura no memoneto', fontsize = 25, pad = 20)
grafico.legend(['Temperetaura'], loc = 'lower right', fontsize = 15)
grafico.grid(True)
grafico.set_xlabel('Ano', fontsize=20)
grafico.set_ylabel('Temperatura', fontsize = 20)
grafico.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))

grafico2.plot(df['data'], df['temperatura'], color = 'b')
grafico2.set_title('Temperatura no memoneto', fontsize = 15)
grafico2.legend(['Temperetaura'], loc = 'best', fontsize = 8)
grafico2.grid(True)
grafico2.set_xlabel('Ano', fontsize = 10)
grafico2.set_ylabel('Temperatura', fontsize=10)
grafico2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
# Out:
# (16071.0, 16436.0)

# %%
figura = plt.figure(figsize = (15, 8))

grafico = figura.add_axes([0, 0, 1, 1])
grafico2 = figura.add_axes([0.7, 0.65, 0.3, 0.3])

grafico.plot(df['data'], df['temperatura'], color = 'green')
grafico.set_title('Temperatura em Maio/2014', fontsize = 25, pad = 20)
grafico.legend(['Temperetaura'], loc = 'lower right', fontsize = 15)
grafico.grid(True)
grafico.set_xlabel('Ano', fontsize=20)
grafico.set_ylabel('Temperatura', fontsize = 20)
grafico.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
grafico.set_ylim(270, 310)


grafico2.plot(df['data'], df['temperatura'], color = 'b')
grafico2.set_title('Temperatura 2014', fontsize = 15)
grafico2.legend(['Temperetaura'], loc = 'best', fontsize = 8)
grafico2.grid(True)
grafico2.set_xlabel('Ano', fontsize = 10)
grafico2.set_ylabel('Temperatura', fontsize=10)
grafico2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
# Out:
# (16071.0, 16436.0)

# %%
figura = plt.figure(figsize = (15, 8))

grafico = figura.add_axes([0, 0, 1, 1])
grafico2 = figura.add_axes([0.7, 0.65, 0.3, 0.3])

grafico.plot(df['data'], df['temperatura'], color = 'green')
grafico.set_title('Temperatura em Maio/2014', fontsize = 25, pad = 20)
grafico.legend(['Temperetaura'], loc = 'lower right', fontsize = 15)
grafico.grid(True)
grafico.set_xlabel('Ano', fontsize=20)
grafico.set_ylabel('Temperatura', fontsize = 20)
grafico.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
grafico.set_ylim(270, 310)

azul_esquerda = df['data'] < datetime.datetime(2014,5,1)
azul_direita = df['data'] > datetime.datetime(2014,6,1)

grafico2.plot(df['data'], df['temperatura'], color = 'g')
grafico2.plot(df['data'][azul_esquerda], df[azul_esquerda]['temperatura'], color = 'b')
grafico2.plot(df[azul_direita]['data'], df[azul_direita]['temperatura'], color = 'b')
grafico2.set_title('Temperatura 2014', fontsize = 15)
grafico2.legend(['Temperetaura'], loc = 'best', fontsize = 8)
grafico2.grid(True)
grafico2.set_xlabel('Ano', fontsize = 10)
grafico2.set_ylabel('Temperatura', fontsize=10)
grafico2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
# Out:
# (16071.0, 16436.0)

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temeperatura no momenro', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'upper right', fontsize = 15)
eixo.grid(True)

eixo.axhline(max(df['temperatura']), color = 'red', linestyle = '--')
eixo.axhline(min(df['temperatura']), color = 'red', linestyle = '--')

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temeperatura no momenro', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])

eixo.annotate("Máximo", xy = (x1,y1), fontsize=20)


eixo.axhline(max(df['temperatura']), color = 'red', linestyle = '--')
eixo.axhline(min(df['temperatura']), color = 'red', linestyle = '--')

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temeperatura no momenro', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmax() - 7000]
y2 = max(df['temperatura']) - 5


eixo.annotate("Máximo", xy = (x1,y1), fontsize=20, xytext=(x2, y2), arrowprops = dict(facecolor = 'red'))


eixo.axhline(max(df['temperatura']), color = 'red', linestyle = '--')
eixo.axhline(min(df['temperatura']), color = 'red', linestyle = '--')

# %%
fig = plt.figure(figsize = (15, 8))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temeperatura no momenro', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize = 20)
eixo.set_ylabel('Temperatura', fontsize = 20)
eixo.legend(['Temperatura'], loc = 'lower right', fontsize = 15)
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmax() - 7000]
y2 = max(df['temperatura']) - 5

x3 = df['data'][df['temperatura'].idxmin()]
y3 = min(df['temperatura'])

x4 = df['data'][df['temperatura'].idxmin() - 7000]
y4 = y3 + 5 

eixo.annotate("Mínimo", xy = (x3, y3), fontsize=20, xytext = (x4, y4), arrowprops=dict(facecolor='red') )


eixo.annotate("Máximo", xy = (x1,y1), fontsize=20, xytext=(x2, y2), arrowprops = dict(facecolor = 'red'))


eixo.axhline(max(df['temperatura']), color = 'red', linestyle = '--')
eixo.axhline(min(df['temperatura']), color = 'red', linestyle = '--')

# %% [markdown]
# # Aula 4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    comprimento_sépala  largura_sépala  comprimento_pétala  largura_pétala  \
# 0                 5.1             3.5                 1.4             0.2
# 1                 4.9             3.0                 1.4             0.2
# 2                 4.7             3.2                 1.3             0.2
# 3                 4.6             3.1                 1.5             0.2
# 4                 5.0             3.6                 1.4             0.2
#
#        espécie
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(df['comprimento_sépala'], df['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize = 25, pad = 10)
eixo.set_xlabel('Comprimento da sépala', fontsize = 15)
eixo.set_ylabel('Largura da sépala', fontsize = 15)
# Out:
# Text(0, 0.5, 'Largura da sépala')

# %%
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(df['comprimento_sépala'], df['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize = 25, pad = 10)
eixo.set_xlabel('Comprimento da sépala', fontsize = 15)
eixo.set_ylabel('Largura da sépala', fontsize = 15)
eixo.tick_params(labelsize = 15)

# %%
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa': 'red',
         'Iris-versicolor':'b',
         'Iris-virginica': 'g'}

for especie in df['espécie'].unique():
    tmp = df[df['espécie'] == especie]
    eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'], color = cores[especie])
    
eixo.set_title('Gráfico de dispersão', fontsize = 25, pad = 10)
eixo.set_xlabel('Comprimento da sépala', fontsize = 15)
eixo.set_ylabel('Largura da sépala', fontsize = 15)
eixo.tick_params(labelsize = 15)
eixo.legend(cores, fontsize = 15, loc = 'upper right')

# %%
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa': 'red',
         'Iris-versicolor':'b',
         'Iris-virginica': 'g'}

marcadores = {'Iris-setosa': 'o',
         'Iris-versicolor':'v',
         'Iris-virginica': 'x'}

for especie in df['espécie'].unique():
    tmp = df[df['espécie'] == especie]
    eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'], color = cores[especie], marker = marcadores[especie])
    
eixo.set_title('Gráfico de dispersão', fontsize = 25, pad = 10)
eixo.set_xlabel('Comprimento da sépala', fontsize = 15)
eixo.set_ylabel('Largura da sépala', fontsize = 15)
eixo.tick_params(labelsize = 15)
eixo.legend(cores, fontsize = 15, loc = 'upper right')

# %%
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa': 'red',
         'Iris-versicolor':'b',
         'Iris-virginica': 'g'}

marcadores = {'Iris-setosa': 'o',
         'Iris-versicolor':'v',
         'Iris-virginica': 'x'}

for especie in df['espécie'].unique():
    tmp = df[df['espécie'] == especie]
    eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'], color = cores[especie], 
                 marker = marcadores[especie], s=100)
    
eixo.set_title('Gráfico de dispersão', fontsize = 25, pad = 10)
eixo.set_xlabel('Comprimento da sépala', fontsize = 15)
eixo.set_ylabel('Largura da sépala', fontsize = 15)
eixo.tick_params(labelsize = 15)
eixo.legend(cores, fontsize = 15, loc = 'upper right')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(df['largura_pétala'])
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(['largura da pétala'])
# Out:
# [Text(1, 0, 'largura da pétala')]

# %%
df.head()
# Out:
#    comprimento_sépala  largura_sépala  comprimento_pétala  largura_pétala  \
# 0                 5.1             3.5                 1.4             0.2
# 1                 4.9             3.0                 1.4             0.2
# 2                 4.7             3.2                 1.3             0.2
# 3                 4.6             3.1                 1.5             0.2
# 4                 5.0             3.6                 1.4             0.2
#
#        espécie
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
fig = plt.figure(figsize = (8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(df.drop('espécie', axis=1))
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1).columns)
# Out:
# [Text(1, 0, 'comprimento_sépala'),
#  Text(2, 0, 'largura_sépala'),
#  Text(3, 0, 'comprimento_pétala'),
#  Text(4, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize = (8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(df.drop('espécie', axis=1), patch_artist = True)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1).columns)
# Out:
# [Text(1, 0, 'comprimento_sépala'),
#  Text(2, 0, 'largura_sépala'),
#  Text(3, 0, 'comprimento_pétala'),
#  Text(4, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize = (8,5))
eixo = fig.add_axes([0,0,1,1])

cores = ['red', 'blue', 'orange', 'green']

caixas = eixo.boxplot(df.drop('espécie', axis=1), patch_artist = True)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1).columns)

for cor, caixa in zip(cores, caixas['boxes']):
    caixa.set(color = cor)

# %%
fig = plt.figure(figsize = (8,5))
eixo = fig.add_axes([0,0,1,1])

cores = ['red', 'blue', 'orange', 'green']

caixas = eixo.boxplot(df.drop('espécie', axis=1), patch_artist = True)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1).columns)

for cor, caixa in zip(cores, caixas['boxes']):
    caixa.set(color = cor)
    
for outlier in caixas['fliers']:
    outlier.set(marker = 'x', markersize = 8)

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(df['comprimento_pétala'])
eixo.set_title('Hostograma', fontsize=15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(df['comprimento_pétala'], bins = 20)
eixo.set_title('Histograma', fontsize=15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(df['comprimento_pétala'], bins = 20, density = True)
eixo.set_title('Histograma', fontsize=15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

eixo.hist(df['comprimento_pétala'], bins = 20)
eixo.set_title('Histograma', fontsize=15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)
eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma),
             xy = (4.5, 20), fontsize = 20)
# Out:
# Text(4.5, 20, '$mu = 3.76$\n$sigma = 1.76$')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

eixo.hist(df['comprimento_pétala'], bins = 20)
eixo.set_title('Histograma', fontsize=15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)
eixo.annotate('$mu = {0:.2f}$\n$sigma = {1:.2f}$'.format(mu, sigma),
             xy = (4.5, 20), fontsize = 20)
eixo.axvline(mu, color = 'k', linestyle = '--')
eixo.annotate('média', xy=(mu-1.3, 28), fontsize = 20)
# Out:
# Text(2.4586666666666694, 28, 'média')

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

eixo.hist(df['comprimento_pétala'], bins = 20)
eixo.set_title('Histograma', fontsize=15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)
eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
             xy = (4.5, 20), fontsize = 20)
eixo.axvline(mu, color = 'k', linestyle = '--')
eixo.annotate('média', xy=(mu-1.3, 28), fontsize = 20)

eixo.axvline(df['comprimento_pétala'].median(), color = 'red', linestyle = '--')
eixo.annotate('mediana', xy=(df['comprimento_pétala'].median() + 0.3, 28), fontsize = 20, color = 'red')
# Out:
# Text(4.6499999999999995, 28, 'mediana')

# %%
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,0.5,0.5])

df_iv = df[df['espécie'] == 'Iris-versicolor']

mu, sigma = df_iv['comprimento_pétala'].mean(), df_iv['comprimento_pétala'].std()

eixo.hist(df_iv['comprimento_pétala'], bins = 20)
eixo.set_title('Iris Versicolor', fontsize=15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)
eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
             xy = (4.6, 6), fontsize = 20)
eixo.axvline(mu, color = 'k', linestyle = '--')
eixo.annotate('média', xy=(mu-0.5, 5.5), fontsize = 20)

eixo.axvline(df_iv['comprimento_pétala'].median(), color = 'red', linestyle = '--')
eixo.annotate('mediana', xy=(df_iv['comprimento_pétala'].median() - 0.7, 6.5), fontsize = 20, color = 'red')

fig.savefig('histograma_iv.png', bbox_inches = 'tight')

# %%
eixo = fig.add_axes([0.5,0.5,1,1])

df_is = df[df['espécie'] == 'Iris-setosa']

mu, sigma = df_is['comprimento_pétala'].mean(), df_is['comprimento_pétala'].std()

eixo.hist(df_is['comprimento_pétala'], bins = 20)
eixo.set_title('Iris setosa', fontsize=15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)
eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
             xy = (1.7, 7), fontsize = 20)
eixo.axvline(mu, color = 'k', linestyle = '--')
eixo.annotate('média', xy=(mu-0.2, 13.5), fontsize = 20)

eixo.axvline(df_is['comprimento_pétala'].median(), color = 'red', linestyle = '--')
eixo.annotate('mediana', xy=(df_is['comprimento_pétala'].median() + 0.05, 12), fontsize = 20, color = 'red')
# Out:
# <ipython-input-104-5c7b1dd20531>:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   eixo = fig.add_axes([0.5,0.5,1,1])
# Text(1.55, 12, 'mediana')

# %%
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,0.5,0.5])

df_ivc = df[df['espécie'] == 'Iris-virginica']

mu, sigma = df_ivc['comprimento_pétala'].mean(), df_ivc['comprimento_pétala'].std()

eixo.hist(df_ivc['comprimento_pétala'], bins = 20)
eixo.set_title('Iris setosa', fontsize=15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)
eixo.grid(True)
eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
             xy = (6.3, 5.7), fontsize = 20)
eixo.axvline(mu, color = 'k', linestyle = '--')
eixo.annotate('média', xy=(mu, 7.8), fontsize = 20)

eixo.axvline(df_ivc['comprimento_pétala'].median(), color = 'red', linestyle = '--')
eixo.annotate('mediana', xy=(df_ivc['comprimento_pétala'].median() + 0.05, 7), fontsize = 20, color = 'red')
# Out:
# Text(5.6, 7, 'mediana')

# %%
from PIL import Image

largura, altura = Image.open('histograma_ivc.png').size
